# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv')

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.shape
# Out:
# (8425, 23)

# %%
data.isna().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
data['MinTemp']=data['MinTemp'].fillna(data['MinTemp'].mean())

# %%
data.isna().sum()
# Out:
# Date                0
# Location            0
# MinTemp             0
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
data['MaxTemp']=data['MaxTemp'].fillna(data['MaxTemp'].mean())

# %%
data['Rainfall'].nunique()
# Out:
# 250

# %%
data['Rainfall']=data['Rainfall'].fillna(data['Rainfall'].mean())

# %%
data['Evaporation'].nunique()
# Out:
# 116

# %%
data['Evaporation']=data['Evaporation'].fillna(data['Evaporation'].mean())

# %%
data['Sunshine'].nunique()
# Out:
# 140

# %%
data['Sunshine']=data['Sunshine'].fillna(data['Sunshine'].mean())

# %%
#data['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', nan, 'ENE',
#        'SSE', 'S', 'NW', 'SE', 'ESE', 'E', 'SSW'], dtype=object)

# %%
data['WindGustSpeed'].unique()
# Out:
# array([ 44.,  46.,  24.,  41.,  56.,  50.,  35.,  80.,  28.,  30.,  31.,
#         61.,  nan,  22.,  63.,  43.,  26.,  33.,  57.,  48.,  39.,  37.,
#         52.,  98.,  54.,  83.,  59.,  70.,  69.,  17.,  20.,  19.,  15.,
#         13.,  11.,  72.,  85.,  65.,  78., 107.,  74.,  67.,  94.,  76.,
#         81.,  87.,   9.,  93.,   7.,  91.,  89., 102., 100.])

# %%
data['WindGustSpeed']=data['WindGustSpeed'].fillna(data['WindGustSpeed'].mean())

# %%
data['WindDir9am'].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
data['WindDir9am'].value_counts()
# Out:
# N      906
# SW     704
# NW     625
# WSW    543
# SE     505
# WNW    480
# SSW    467
# ENE    433
# NNE    430
# W      414
# NE     409
# S      402
# E      380
# SSE    365
# NNW    280
# ESE    253
# Name: WindDir9am, dtype: int64

# %%
data['WindDir3pm'].unique()
# Out:
# array(['WNW', 'WSW', 'E', 'NW', 'W', 'SSE', 'ESE', 'ENE', 'NNW', 'SSW',
#        'SW', 'SE', 'N', 'S', 'NNE', nan, 'NE'], dtype=object)

# %%
data['WindDir3pm'].value_counts()
# Out:
# SE     813
# S      742
# SSE    623
# WSW    580
# NE     544
# N      524
# SW     494
# WNW    487
# NW     468
# W      462
# ESE    462
# E      460
# ENE    417
# SSW    370
# NNE    365
# NNW    306
# Name: WindDir3pm, dtype: int64

# %%
data['WindSpeed9am'].unique()
# Out:
# array([20.,  4., 19., 11.,  7.,  6., 15., 17., 28., 24., nan,  9.,  0.,
#        13.,  2., 26., 30., 22., 35., 37., 31., 33., 43., 41., 46., 39.,
#        56., 54., 50., 52., 44., 61., 57., 48., 63.])

# %%
data['WindSpeed9am']=data['WindSpeed9am'].fillna(data['WindSpeed9am'].mean())

# %%
data['WindSpeed3pm'].unique()
# Out:
# array([24., 22., 26.,  9., 20., 17., 28., 11.,  6., 13., 30., 19., 31.,
#         7., 15., 48.,  4., 33.,  0.,  2., nan, 37., 46., 39., 50., 35.,
#        41., 44., 43., 65., 56., 83., 54., 61., 57., 52.])

# %%
data['WindSpeed9pm']=data['WindSpeed3pm'].fillna(data['WindSpeed3pm'].mean())

# %%
data['Humidity9am'].unique()
# Out:
# array([ 71.,  44.,  38.,  45.,  82.,  55.,  49.,  48.,  42.,  58.,  89.,
#         76.,  65.,  57.,  50.,  69.,  80.,  47.,  56.,  54.,  41.,  78.,
#         46.,  43.,  33.,  34.,  36.,  52.,  51.,  40.,  35.,  39.,  60.,
#         37.,  27.,  32.,  53.,  20.,  66.,  63.,  62.,  87.,  61.,  59.,
#         92.,  72.,  67.,  75.,  88.,  68.,  73.,  74.,  83.,  77.,  70.,
#         81.,  86.,  97.,  99.,  91.,  85.,  93.,  84.,  94.,  79.,  98.,
#         96.,  95.,  90.,  64.,  29.,  21., 100.,  30.,  23.,  nan,  31.,
#         22.,  28.,  25.,  16.,  19.,  17.,  18.,  14.,  10.,  12.,  11.,
#         24.,  26.,  15.])

# %%
data['Humidity9am']=data['Humidity9am'].fillna(data['Humidity9am'].mean())

# %%
data['Humidity3pm'].unique()
# Out:
# array([22., 25., 30., 16., 33., 23., 19.,  9., 27., 91., 93., 43., 32.,
#        28., 82., 65., 26., 24., 17., 15., 70., 12.,  8., 31., 20., 10.,
#        21., 39., 13., 11., 69., 18., 14., 35., 90., 68., 74., 41., 34.,
#        78., 49., 37., 42., 47., 52., 29., 86., 89., 62., 79., 48., 46.,
#        38., 44., 51., 36., 45., 40., 53., 61., 59., 63., 54., 57., 50.,
#        58., 75., 97., 80., 95., 56., 72., 60., 71., 73., 81., 76., 64.,
#        87., 85., 67., 55., 77., 84.,  7., 99., 92., 66., 83., 94., 96.,
#        88., nan, 98.,  6.])

# %%
data['Humidity3pm']=data['Humidity3pm'].fillna(data['Humidity3pm'].mean())

# %%
data['Pressure9am'].unique()
# Out:
# array([1007.7, 1010.6, 1007.6, 1017.6, 1010.8, 1009.2, 1009.6, 1013.4,
#        1008.9, 1007. , 1011.8, 1010.5,  994.3, 1001.2, 1009.7, 1012.2,
#        1005.8, 1009.4, 1019.2, 1019.3, 1013.6, 1007.8, 1011. , 1012.9,
#        1010.9, 1006.8, 1005.2, 1004.8, 1005.6, 1006.1, 1004.5, 1014.4,
#        1018.7, 1015.1, 1012.6, 1011.9, 1017.8, 1009.9, 1014.1, 1015.7,
#        1011.6, 1008.4, 1019.7, 1015.8, 1010.1, 1005.3, 1007.9, 1005.4,
#        1016.5, 1017.7, 1014.9, 1014.6, 1014.2, 1012.5, 1011.7, 1008.8,
#        1005.9, 1008. , 1008.2, 1009.3, 1012.8, 1017. , 1023.3, 1022.5,
#        1016.2, 1017.2, 1012.4, 1015.6, 1013. , 1014. , 1016.6, 1007.5,
#        1014.7, 1014.5, 1013.7, 1015.2, 1019.5, 1021.3, 1017.4, 1012.7,
#        1013.3, 1016.3, 1014.8, 1019.1, 1023. , 1023.8, 1022.4, 1023.2,
#        1022.6, 1018.8, 1019.8, 1020.4, 1021.8, 1026.7, 1027.1, 1024.2,
#        1021.5, 1024.4, 1024.1, 1018.5, 1022.8, 1022.7, 1023.6, 1025.2,
# ...

# %%
data['Pressure9am']=data['Pressure9am'].fillna(data['Pressure9am'].mean())

# %%
data['Pressure3pm'].unique()
# Out:
# array([1007.1, 1007.8, 1008.7, 1012.8, 1006. , 1005.4, 1008.2, 1010.1,
#        1003.6, 1005.7, 1004.2,  993. , 1001.8, 1010.3, 1010.4, 1002.2,
#        1009.7, 1017.1, 1014.8, 1008.1, 1007.6, 1001.7, 1003.4, 1005.1,
#        1003.2, 1013.1, 1009.2, 1006.7, 1002.7, 1010.9, 1013.7, 1006.8,
#        1012.1, 1006.9, 1012.7, 1017.4, 1016.2, 1010.6, 1004.8, 1005.9,
#         997.8, 1003.9, 1014.6, 1014.1, 1011.6, 1011.8, 1010.2, 1010.5,
#        1007.4, 1004.7, 1002.6, 1005. , 1003.8, 1006.5, 1008.5, 1011.1,
#        1017.3, 1019.7, 1016.4, 1013.8, 1013.5, 1007.5, 1004.5, 1010.8,
#        1012.4, 1013.4, 1015. , 1012.6, 1004.6, 1009. , 1012. , 1014.7,
#        1015.9, 1018. , 1018.9, 1008. , 1013.2, 1013.9, 1013.6, 1014.4,
#        1019.2, 1017.2, 1020.7, 1020.6, 1019.1, 1019.5, 1019.4, 1018.4,
#        1012.9, 1019.3, 1016.5, 1019.6, 1023.5, 1023.4, 1017.7, 1020.3,
#        1020.8, 1018.7, 1009.8, 1016.8, 1020. , 1020.9, 1021.6, 1015.7,
# ...

# %%
data['Pressure3pm']=data['Pressure3pm'].fillna(data['Pressure3pm'].mean())

# %%
data['Cloud9am'].unique()
# Out:
# array([ 8., nan,  7.,  1.,  0.,  5.,  4.,  2.,  6.,  3.])

# %%
data['Cloud9am'].value_counts()
# Out:
# 7.0    1418
# 1.0    1038
# 8.0    1015
# 0.0     554
# 6.0     551
# 5.0     414
# 3.0     384
# 2.0     357
# 4.0     273
# Name: Cloud9am, dtype: int64

# %%
data['Cloud9am']=data['Cloud9am'].fillna(data['Cloud9am'].mean())

# %%
data['Cloud3pm'].value_counts()
# Out:
# 7.0    1294
# 1.0    1077
# 8.0     863
# 6.0     597
# 5.0     522
# 2.0     508
# 3.0     411
# 4.0     351
# 0.0     347
# Name: Cloud3pm, dtype: int64

# %%
data['Cloud3pm']=data['Cloud3pm'].fillna(data['Cloud3pm'].mean())

# %%
data['Temp9am'].unique()
# Out:
# array([16.9, 17.2, 21. , 18.1, 17.8, 20.6, 16.3, 18.3, 20.1, 20.4, 15.9,
#        17.4, 15.8, 17.3, 18. , 15.5, 19.1, 24.5, 23.8, 20.9, 21.5, 23.2,
#        26.6, 24.6, 21.6, 12.5, 19.7, 14.9, 17.1, 20.7, 22.4, 23.1, 25.2,
#        17.9, 20.2, 22.8, 24.2, 24.3, 25.6, 27.6, 16. , 22. , 26.8, 27.3,
#        26.1, 23.3, 21.2, 23.4, 25.8, 28.2, 29. , 29.2, 29.9, 32.4, 28.8,
#        27.2, 25.5, 26.5, 28.7, 29.6, 34.5, 18.7, 16.7, 17. , 19.2, 21.4,
#        22.1, 19.3, 15. , 20. , 22.2, 23. , 15.6, 13.9, 12.6, 13.3, 17.6,
#        18.6, 19. , 19.9, 12.7, 12.2, 12.1, 14.7, 18.8, 15.4, 16.2, 16.5,
#        14. , 16.6, 18.4, 12.9, 13.8, 15.1, 16.4, 16.1, 20.5,  9.6, 12.4,
#        14.1, 11.2,  9.5,  7.6, 10.1,  8.2,  7.9,  7.2, 10.6, 10.3, 10. ,
#         8.3, 11. ,  9.4, 11.7,  8.5,  9.1,  7.5, 13. ,  7. ,  8.8,  7.4,
#        11.9, 11.6, 13.6,  7.1, 10.2,  8. ,  9.2, 11.3,  4.7,  6.8,  4.9,
#         2.2,  1.9,  5.9,  6.5,  5.4,  6.6,  5.6,  6.9,  8.4,  9.8, 13.5,
# ...

# %%
data['Temp9am']=data['Temp9am'].fillna(data['Temp9am'].mean())

# %%
data['Temp3pm'].unique()
# Out:
# array([21.8, 24.3, 23.2, 26.5, 29.7, 28.9, 24.6, 25.5, 30.2, 28.2, 28.8,
#        17. , 15.8, 19.8, 23.5, 26.2, 18.1, 21.5, 21. , 27.3, 31.6, 30.8,
#        29. , 31.2, 33. , 32.1, 26.1, 18.2, 22.7, 25.7, 22.1, 33.9, 34.4,
#        36.8, 38.4, 27.6, 26.6, 29.3, 30. , 33.2, 35.7, 41.5, 27.1, 25.8,
#        30.5, 37.7, 36.1, 33.1, 36.5, 36.2, 39.2, 40.1, 41.2, 42. , 41.9,
#        37.1, 35.2, 39.7, 41.6, 43.4, 38.5, 29.4, 24.9, 17.3, 28.5, 29.2,
#        29.5, 27. , 30.7, 32.7, 26.8, 29.8, 31.3, 33.4, 28.6, 33.6, 28.1,
#        21.9, 21.4, 22. , 29.6, 18.8, 23.8, 19.7, 18.3, 20.5, 23.9, 27.2,
#        32.6, 33.5, 31.4, 19.6, 27.7, 29.9, 30.9, 27.4, 20.3, 21.2, 20.9,
#        21.6, 25. , 24.4, 23.1, 18.9, 19.4, 22.9, 23.6, 21.3, 22.3, 22.6,
#        15.1, 14.5, 11.6,  9.4, 14. , 12.1, 16.1, 16.3, 19.1, 18.5, 18.4,
#        19.2, 20.2, 17.7, 18. , 14.6, 15.3, 15.9, 14.7, 18.7, 21.7, 20.8,
#        19.5, 17.4, 15.6, 16.7, 16.8, 13.4, 13. , 16.5, 10.2, 11.5, 11.4,
# ...

# %%
data['Temp3pm']=data['Temp3pm'].fillna(data['Temp3pm'].mean())

# %%
data['RainToday'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data['RainTomorrow'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data.dropna(subset=['RainToday'],inplace=True)
data.dropna(subset=['RainTomorrow'],inplace=True)

# %%
data.isna().sum()
# Out:
# Date                0
# Location            0
# MinTemp             0
# MaxTemp             0
# Rainfall            0
# Evaporation         0
# Sunshine            0
# WindGustDir       945
# WindGustSpeed     945
# WindDir9am        795
# WindDir3pm        283
# WindSpeed9am        0
# WindSpeed3pm       83
# Humidity9am         0
# Humidity3pm         0
# Pressure9am         0
# Pressure3pm         0
# Cloud9am         2207
# Cloud3pm            0
# Temp9am             0
# Temp3pm             0
# RainToday           0
# RainTomorrow        0
# WindSpeed9pm        0
# dtype: int64

# %%
data['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', 'ENE', 'SSE',
#        'S', 'NW', 'SE', 'ESE', nan, 'E', 'SSW'], dtype=object)

# %%
data.dropna(subset=['WindGustDir'],inplace=True)

# %%
data['WindDir9am'].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', 'SSW', 'N', 'WSW',
#        'ESE', 'E', nan, 'NW', 'WNW', 'NNE'], dtype=object)

# %%
data.dropna(subset=['WindDir9am'],inplace=True)

# %%
data['WindDir3pm'].unique()
# Out:
# array(['WNW', 'WSW', 'E', 'NW', 'W', 'SSE', 'ESE', 'ENE', 'NNW', 'SSW',
#        'SW', 'SE', 'N', 'S', 'NNE', 'NE', nan], dtype=object)

# %%
data.dropna(subset=['WindDir3pm'],inplace=True)

# %%
data['WindSpeed3pm'].unique()
# Out:
# array([24., 22., 26.,  9., 20., 17., 28., 11.,  6., 13., 19., 30., 31.,
#         7., 15., 48.,  4., 33.,  2., 37., 39., 50., 35., 41., 44., 43.,
#        46., 56., 54., 61., 52.])

# %%
data['WindSpeed3pm'].value_counts()
# Out:
# 20.0    545
# 13.0    538
# 17.0    511
# 19.0    472
# 24.0    469
# 15.0    468
# 9.0     464
# 11.0    462
# 22.0    406
# 28.0    360
# 26.0    349
# 7.0     263
# 30.0    245
# 31.0    242
# 6.0     193
# 33.0    157
# 35.0    128
# 4.0     112
# 37.0     94
# 39.0     68
# 41.0     38
# 2.0      37
# 43.0     31
# 46.0     19
# 44.0     16
# 48.0      9
# 50.0      7
# 52.0      7
# 56.0      2
# 54.0      2
# 61.0      2
# Name: WindSpeed3pm, dtype: int64

# %%
data.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# WindSpeed9pm     0
# dtype: int64

# %%
data.shape
# Out:
# (6716, 24)

# %%
data.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow', 'WindSpeed9pm'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6716 entries, 0 to 8423
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           6716 non-null   object
#  1   Location       6716 non-null   object
#  2   MinTemp        6716 non-null   float64
#  3   MaxTemp        6716 non-null   float64
#  4   Rainfall       6716 non-null   float64
#  5   Evaporation    6716 non-null   float64
#  6   Sunshine       6716 non-null   float64
#  7   WindGustDir    6716 non-null   object
#  8   WindGustSpeed  6716 non-null   float64
#  9   WindDir9am     6716 non-null   object
#  10  WindDir3pm     6716 non-null   object
#  11  WindSpeed9am   6716 non-null   float64
#  12  WindSpeed3pm   6716 non-null   float64
#  13  Humidity9am    6716 non-null   float64
#  14  Humidity3pm    6716 non-null   float64
#  15  Pressure9am    6716 non-null   float64
#  16  Pressure3pm    6716 non-null   float64
# ...

# %%
data.nunique()
# Out:
# Date             2830
# Location           11
# MinTemp           278
# MaxTemp           329
# Rainfall          230
# Evaporation       113
# Sunshine          141
# WindGustDir        16
# WindGustSpeed      50
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       32
# WindSpeed3pm       31
# Humidity9am        91
# Humidity3pm        95
# Pressure9am       375
# Pressure3pm       370
# Cloud9am           10
# Cloud3pm           10
# Temp9am           293
# Temp3pm           325
# RainToday           2
# RainTomorrow        2
# WindSpeed9pm       31
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  5266.000000  5266.000000  5266.000000  5266.000000  5266.000000
# mean     13.457877    24.379966     2.745404     5.345501     7.850129
# std       5.481137     6.243559     9.298133     3.076884     2.976449
# min      -1.300000     8.200000     0.000000     0.000000     0.000000
# 25%       9.400000    19.800000     0.000000     3.600000     7.632205
# 50%      13.450000    23.800000     0.000000     5.389395     7.632205
# 75%      17.700000    28.800000     0.800000     6.000000     9.800000
# max      28.500000    45.500000   225.000000    59.200000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    5266.000000   5266.000000   5266.000000  5266.000000  5266.000000
# mean       39.804596     14.599126     18.737562    65.627957    49.644037
# std        14.099860      9.128572      8.815502    17.144974    18.781438
# ...

# %%
data['Rainfall']=data['Rainfall'].replace(0,data['Rainfall'].mean())
data['Evaporation']=data['Evaporation'].replace(0,data['Evaporation'].mean())
data['Sunshine']=data['Sunshine'].replace(0,data['Sunshine'].mean())
data['Cloud9am']=data['Cloud9am'].replace(0,data['Cloud9am'].mean())
data['Cloud3pm']=data['Cloud3pm'].replace(0,data['Cloud3pm'].mean())

# %%
data.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  5266.000000  5266.000000  5266.000000  5266.000000  5266.000000
# mean     13.457877    24.379966     4.570113     5.351592     8.005164
# std       5.481137     6.243559     8.838245     3.071582     2.760061
# min      -1.300000     8.200000     0.200000     0.200000     0.100000
# 25%       9.400000    19.800000     2.745404     3.600000     7.632205
# 50%      13.450000    23.800000     2.745404     5.389395     7.632205
# 75%      17.700000    28.800000     2.745404     6.000000     9.800000
# max      28.500000    45.500000   225.000000    59.200000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    5266.000000   5266.000000   5266.000000  5266.000000  5266.000000
# mean       39.804596     14.599126     18.737562    65.627957    49.644037
# std        14.099860      9.128572      8.815502    17.144974    18.781438
# ...

# %%
# each column counts equal no missing value
# target variable is a categorical variable so its classification model
# duplicate rows removed

# %%
# date column datatype is object change to date format
data['Date']=pd.to_datetime(data['Date'])
data['Month']=data['Date'].apply(lambda x:x.month)
data['Day']=data['Date'].apply(lambda x:x.day)

# %%
# check categorical column
categorical_col=[]
for i in data.dtypes.index:
    if data.dtypes[i]=='object':
        categorical_col.append(i)
print('categorical column :',categorical_col)
print('\n')
# check neumerical column
contineous_col=[]
for i in data.dtypes.index:
    if data.dtypes[i]!='object':
        contineous_col.append(i)
print('contineous columns :',contineous_col)
print('\n')
# Out:
# categorical column : ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']
#
#
# contineous columns : ['Date', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'WindSpeed9pm', 'Month', 'Day']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5266 entries, 0 to 8423
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           5266 non-null   datetime64[ns]
#  1   Location       5266 non-null   object
#  2   MinTemp        5266 non-null   float64
#  3   MaxTemp        5266 non-null   float64
#  4   Rainfall       5266 non-null   float64
#  5   Evaporation    5266 non-null   float64
#  6   Sunshine       5266 non-null   float64
#  7   WindGustDir    5266 non-null   object
#  8   WindGustSpeed  5266 non-null   float64
#  9   WindDir9am     5266 non-null   object
#  10  WindDir3pm     5266 non-null   object
#  11  WindSpeed9am   5266 non-null   float64
#  12  WindSpeed3pm   5266 non-null   float64
#  13  Humidity9am    5266 non-null   float64
#  14  Humidity3pm    5266 non-null   float64
#  15  Pressure9am    5266 non-null   float64
#  16  Pressure3pm    5266 non-null   float64
# ...

# %%
# visualise tomorrow rain count
ax=sns.countplot(x='RainTomorrow',data=data)
print(data['RainTomorrow'].value_counts())
# Out:
# No     4002
# Yes    1264
# Name: RainTomorrow, dtype: int64

# %%
# # rain tomorrow 'no' count is higher so class imbalance present
# visualise rain today count 
ax=sns.countplot(x='RainToday',data=data)
print(data['RainToday'].value_counts())
# Out:
# No     3997
# Yes    1269
# Name: RainToday, dtype: int64

# %%
# raintoday 'no' count higher than 'yes'
# visualise location count
ax=sns.countplot(x='Location',data=data)
print(data['Location'].value_counts())
# Out:
# PerthAirport    1164
# Melbourne        703
# Albury           701
# CoffsHarbour     567
# Brisbane         544
# Williamtown      523
# Penrith          369
# Darwin           250
# Wollongong       224
# Adelaide         185
# Uluru             36
# Name: Location, dtype: int64

# %%
# visualise rain today and rain tomorrow
plt.figure(figsize=(15,10),facecolor='r')
sns.scatterplot(x=data['MinTemp'],y=data['MaxTemp'])
plt.xlabel('MinTemp')
plt.ylabel('MaxTemp')
plt.title('MinTemp vs MaxTemp')
plt.show()

# %%
# check normal distribution with distplot
plt.figure(figsize=(15,10),facecolor='r')
p=1
for columns in contineous_col:
    if p<20:
        plt.subplot(5,4,p)
        sns.distplot(data[columns],color='r')
        plt.xlabel(columns,fontsize=15)
    p+=1
plt.show()

# %%
data.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# WindSpeed9pm     0
# Month            0
# Day              0
# dtype: int64

# %%
# we can see that data normally distributed 
# check outliers using boxplot
plt.figure(figsize=(15,10),facecolor='r')
p=1
for columns in data[['MinTemp','MaxTemp','WindSpeed9am','WindSpeed3pm','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','WindSpeed9pm']]:
    if p<12:
        plt.subplot(4,3,p)
        sns.boxplot(data[columns],palette='winter_r')
        plt.xlabel(columns,fontsize=15)
    p+=1
plt.show()

# %%
from numpy import percentile
columns=data[['MaxTemp','WindSpeed9am','WindSpeed3pm','Humidity9am','Pressure9am','Pressure3pm','WindSpeed9pm']]
for i in columns:
    if isinstance(data[i][0],str):
        continue
    else:
        quartiles=percentile(data[i],[25,75])
        lower_level=quartiles[0]-(1.5*(quartiles[1]-quartiles[0]))
        upper_level=quartiles[0]+(1.5*(quartiles[1]-quartiles[0]))
        data[i]=data[i].apply(lambda x: upper_level if x>upper_level else (lower_level if x < lower_level else x))

# %%
# we can see that data normally distributed 
# check outliers using boxplot
plt.figure(figsize=(15,10),facecolor='r')
p=1
for columns in data[['MinTemp','MaxTemp','WindSpeed9am','WindSpeed3pm','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','WindSpeed9pm']]:
    if p<12:
        plt.subplot(4,3,p)
        sns.boxplot(data[columns],palette='winter_r')
        plt.xlabel(columns,fontsize=15)
    p+=1
plt.show()

# %%
data.shape
# Out:
# (5266, 26)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=oe.fit_transform(data[i].values.reshape(-1,1))
data
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    2008-12-01       1.0     13.4     22.9  0.600000     5.389395  7.632205
# 1    2008-12-02       1.0      7.4     25.1  2.745404     5.389395  7.632205
# 2    2008-12-03       1.0     12.9     25.7  2.745404     5.389395  7.632205
# 3    2008-12-04       1.0      9.2     28.0  2.745404     5.389395  7.632205
# 4    2008-12-05       1.0     17.5     32.3  1.000000     5.389395  7.632205
# ...         ...       ...      ...      ...       ...          ...       ...
# 8419 2017-06-20       8.0      3.5     21.8  2.745404     5.389395  7.632205
# 8420 2017-06-21       8.0      2.8     23.4  2.745404     5.389395  7.632205
# 8421 2017-06-22       8.0      3.6     25.3  2.745404     5.389395  7.632205
# 8422 2017-06-23       8.0      5.4     26.9  2.745404     5.389395  7.632205
# 8423 2017-06-24       8.0      7.8     27.0  2.745404     5.389395  7.632205
#
# ...

# %%
data.drop('Date',axis=1,inplace=True)

# %%
data.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0       1.0     13.4     22.9  0.600000     5.389395  7.632205         13.0
# 1       1.0      7.4     25.1  2.745404     5.389395  7.632205         14.0
# 2       1.0     12.9     25.7  2.745404     5.389395  7.632205         15.0
# 3       1.0      9.2     28.0  2.745404     5.389395  7.632205          4.0
# 4       1.0     17.5     32.3  1.000000     5.389395  7.632205         13.0
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0           44.0        13.0        14.0  ...       1007.1  8.000000
# 1           44.0         6.0        15.0  ...       1007.8  4.577622
# 2           46.0        13.0        15.0  ...       1008.7  4.577622
# 3           24.0         9.0         0.0  ...       1012.8  4.577622
# 4           41.0         1.0         7.0  ...       1006.0  7.000000
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  WindSpeed9pm  Month  \
# ...

# %%
#visualise relation between features and target
plt.figure(figsize=(15,10),facecolor='red')
data.corr()['RainTomorrow'].sort_values(ascending=False).drop(['RainTomorrow']).plot(kind='bar',color='m')
plt.xlabel('Featuters',fontsize=15)
plt.ylabel('target',fontsize=15)
plt.title('corelation between fratures and labels')
plt.show()

# %%
# features like day, month ,location,windDr3pm contribute less to the label

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5266 entries, 0 to 8423
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       5266 non-null   float64
#  1   MinTemp        5266 non-null   float64
#  2   MaxTemp        5266 non-null   float64
#  3   Rainfall       5266 non-null   float64
#  4   Evaporation    5266 non-null   float64
#  5   Sunshine       5266 non-null   float64
#  6   WindGustDir    5266 non-null   float64
#  7   WindGustSpeed  5266 non-null   float64
#  8   WindDir9am     5266 non-null   float64
#  9   WindDir3pm     5266 non-null   float64
#  10  WindSpeed9am   5266 non-null   float64
#  11  WindSpeed3pm   5266 non-null   float64
#  12  Humidity9am    5266 non-null   float64
#  13  Humidity3pm    5266 non-null   float64
#  14  Pressure9am    5266 non-null   float64
#  15  Pressure3pm    5266 non-null   float64
#  16  Cloud9am       5266 non-null   float64
# ...

# %%
cor=data.corr()

# %%
cor
# Out:
#                Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location       1.000000  0.068012  0.038563 -0.004625     0.146360  0.047123
# MinTemp        0.068012  1.000000  0.738663  0.090923     0.347301  0.083027
# MaxTemp        0.038563  0.738663  1.000000 -0.074449     0.431358  0.383269
# Rainfall      -0.004625  0.090923 -0.074449  1.000000    -0.026577 -0.128743
# Evaporation    0.146360  0.347301  0.431358 -0.026577     1.000000  0.314320
# Sunshine       0.047123  0.083027  0.383269 -0.128743     0.314320  1.000000
# WindGustDir   -0.048548 -0.192443 -0.274428  0.040531    -0.117705 -0.138246
# WindGustSpeed  0.257226  0.197088  0.105598  0.104538     0.196996  0.006766
# WindDir9am    -0.115575 -0.083107 -0.244118  0.086848    -0.106305 -0.103888
# WindDir3pm     0.002498 -0.155179 -0.181488  0.026994    -0.030733 -0.066865
# WindSpeed9am   0.306188  0.130434  0.003019  0.062662     0.153451  0.021760
# ...

# %%
# visualise relation between features and label using heatmap
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(),annot=True,fmt='.1g')
plt.show()

# %%
# devide dataset into features and label
x=data.drop('RainTomorrow',axis=1)
y=data['RainTomorrow']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
# check multicolinearity using vif
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['features']=x.columns

# %%
vif
# Out:
#     vif values       features
# 0     1.224265       Location
# 1     8.345442        MinTemp
# 2    21.311310        MaxTemp
# 3     1.261744       Rainfall
# 4     1.416941    Evaporation
# 5     1.952985       Sunshine
# 6     1.752196    WindGustDir
# 7     2.616893  WindGustSpeed
# 8     1.358308     WindDir9am
# 9     1.578241     WindDir3pm
# 10    2.057928   WindSpeed9am
# 11         inf   WindSpeed3pm
# 12    4.114959    Humidity9am
# 13    6.055337    Humidity3pm
# 14   18.550324    Pressure9am
# 15   17.821513    Pressure3pm
# 16    1.691113       Cloud9am
# 17    1.648154       Cloud3pm
# 18   17.893250        Temp9am
# 19   28.991418        Temp3pm
# 20    1.635383      RainToday
# 21         inf   WindSpeed9pm
# 22    1.182150          Month
# 23    1.005046            Day

# %%
x.isna().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# WindSpeed9pm     0
# Month            0
# Day              0
# dtype: int64

# %%
x.drop('Temp3pm',axis=1,inplace=True)

# %%
# check multicolinearity using vif
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['features']=x.columns

# %%
vif
# Out:
#     vif values       features
# 0     1.224220       Location
# 1     8.335152        MinTemp
# 2    10.105212        MaxTemp
# 3     1.257671       Rainfall
# 4     1.412604    Evaporation
# 5     1.952165       Sunshine
# 6     1.749035    WindGustDir
# 7     2.615856  WindGustSpeed
# 8     1.353722     WindDir9am
# 9     1.577510     WindDir3pm
# 10    2.056811   WindSpeed9am
# 11         inf   WindSpeed3pm
# 12    3.635591    Humidity9am
# 13    3.678742    Humidity3pm
# 14   17.756209    Pressure9am
# 15   17.087305    Pressure3pm
# 16    1.680011       Cloud9am
# 17    1.647418       Cloud3pm
# 18   15.755879        Temp9am
# 19    1.635334      RainToday
# 20         inf   WindSpeed9pm
# 21    1.141152          Month
# 22    1.004022            Day

# %%
x.drop('WindSpeed9pm',axis=1,inplace=True)

# %%
# check multicolinearity using vif
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['features']=x.columns

# %%
vif
# Out:
#     vif values       features
# 0     1.224220       Location
# 1     8.335152        MinTemp
# 2    10.105212        MaxTemp
# 3     1.257671       Rainfall
# 4     1.412604    Evaporation
# 5     1.952165       Sunshine
# 6     1.749035    WindGustDir
# 7     2.615856  WindGustSpeed
# 8     1.353722     WindDir9am
# 9     1.577510     WindDir3pm
# 10    2.056811   WindSpeed9am
# 11    2.074467   WindSpeed3pm
# 12    3.635591    Humidity9am
# 13    3.678742    Humidity3pm
# 14   17.756209    Pressure9am
# 15   17.087305    Pressure3pm
# 16    1.680011       Cloud9am
# 17    1.647418       Cloud3pm
# 18   15.755879        Temp9am
# 19    1.635334      RainToday
# 20    1.141152          Month
# 21    1.004022            Day

# %%
# slightly high mulicolinearity found in Temp3pm and maxtemp 
# we will check model performance with and with out these features to get a better score
y.value_counts()
# Out:
# 0.0    4002
# 1.0    1264
# Name: RainTomorrow, dtype: int64

# %%
# here we can see the data is not balanced hence its classification problem we will balance the data using oversampling method
# oversampling method
# !pip install imblearn
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x1,y1=sm.fit_resample(x,y)

# %%
y1.value_counts()
# Out:
# 0.0    4002
# 1.0    4002
# Name: RainTomorrow, dtype: int64

# %%
# import libraries
# do non graphical analysis
# do graphical analysis
# encode categorical column
# check outliers if it present remove it
# check multicolinearity if present revome
# apply features scaling method on numerical features
# apply resampling method to balance the class(classification method)
# also apply features selection methods

# %%
# model building 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=i)
    rfc=RandomForestClassifier()
    rfc.fit(x_train,y_train)
    pred=rfc.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print('best accuracy is ',maxaccu,'at random state ',maxrs)
# Out:
# best accuracy is  0.920049968769519 at random state  174

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=maxrs)

# %%
# RandomForestclassifier
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
pred_RFC=RFC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_RFC))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_RFC))
print("\nclassification report \n\n",classification_report(y_test,pred_RFC))
# Out:
# Accuracy score  0.9175515302935665
# confusion matrix
#
#  [[709  93]
#  [ 39 760]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.95      0.88      0.91       802
#          1.0       0.89      0.95      0.92       799
#
#     accuracy                           0.92      1601
#    macro avg       0.92      0.92      0.92      1601
# weighted avg       0.92      0.92      0.92      1601

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_LR))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_LR))
print("\nclassification report \n\n",classification_report(y_test,pred_LR))
# Out:
# Accuracy score  0.8069956277326671
# confusion matrix
#
#  [[653 149]
#  [160 639]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.81      0.81       802
#          1.0       0.81      0.80      0.81       799
#
#     accuracy                           0.81      1601
#    macro avg       0.81      0.81      0.81      1601
# weighted avg       0.81      0.81      0.81      1601

# %%
from sklearn.svm import SVC
SVM=SVC()
SVM.fit(x_train,y_train)
pred_SVM=SVM.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_SVM))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_SVM))
print("\nclassification report \n\n",classification_report(y_test,pred_SVM))
# Out:
# Accuracy score  0.8732042473454091
# confusion matrix
#
#  [[687 115]
#  [ 88 711]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.86      0.87       802
#          1.0       0.86      0.89      0.88       799
#
#     accuracy                           0.87      1601
#    macro avg       0.87      0.87      0.87      1601
# weighted avg       0.87      0.87      0.87      1601

# %%
GBC=GradientBoostingClassifier()
GBC.fit(x_train,y_train)
pred_GBC=GBC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_GBC))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_GBC))
print("\nclassification report \n\n",classification_report(y_test,pred_GBC))
# Out:
# Accuracy score  0.8844472204871955
# confusion matrix
#
#  [[710  92]
#  [ 93 706]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.89      0.88       802
#          1.0       0.88      0.88      0.88       799
#
#     accuracy                           0.88      1601
#    macro avg       0.88      0.88      0.88      1601
# weighted avg       0.88      0.88      0.88      1601

# %%
from sklearn.ensemble import AdaBoostClassifier
ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
pred_ABC=ABC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_ABC))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_ABC))
print("\nclassification report \n\n",classification_report(y_test,pred_ABC))
# Out:
# Accuracy score  0.8513429106808245
# confusion matrix
#
#  [[684 118]
#  [120 679]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.85      0.85       802
#          1.0       0.85      0.85      0.85       799
#
#     accuracy                           0.85      1601
#    macro avg       0.85      0.85      0.85      1601
# weighted avg       0.85      0.85      0.85      1601

# %%
from sklearn.ensemble import BaggingClassifier
BAGG=BaggingClassifier()
BAGG.fit(x_train,y_train)
pred_BAGG=BAGG.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_BAGG))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_BAGG))
print("\nclassification report \n\n",classification_report(y_test,pred_BAGG))
# Out:
# Accuracy score  0.891317926296065
# confusion matrix
#
#  [[727  75]
#  [ 99 700]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89       802
#          1.0       0.90      0.88      0.89       799
#
#     accuracy                           0.89      1601
#    macro avg       0.89      0.89      0.89      1601
# weighted avg       0.89      0.89      0.89      1601

# %%
from sklearn.ensemble import ExtraTreesClassifier
ETC=ExtraTreesClassifier()
ETC.fit(x_train,y_train)
pred_ETC=ETC.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_ETC))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_ETC))
print("\nclassification report \n\n",classification_report(y_test,pred_ETC))
# Out:
# Accuracy score  0.9262960649594004
# confusion matrix
#
#  [[716  86]
#  [ 32 767]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.89      0.92       802
#          1.0       0.90      0.96      0.93       799
#
#     accuracy                           0.93      1601
#    macro avg       0.93      0.93      0.93      1601
# weighted avg       0.93      0.93      0.93      1601

# %%
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()
DT.fit(x_train,y_train)
pred_DT=DT.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_DT))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_DT))
print("\nclassification report \n\n",classification_report(y_test,pred_DT))
# Out:
# Accuracy score  0.8338538413491567
# confusion matrix
#
#  [[653 149]
#  [117 682]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.81      0.83       802
#          1.0       0.82      0.85      0.84       799
#
#     accuracy                           0.83      1601
#    macro avg       0.83      0.83      0.83      1601
# weighted avg       0.83      0.83      0.83      1601

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN=KNeighborsClassifier()
KNN.fit(x_train,y_train)
pred_KNN=KNN.predict(x_test)
print("Accuracy score ",accuracy_score(y_test,pred_KNN))
print("confusion matrix \n\n",confusion_matrix(y_test,pred_KNN))
print("\nclassification report \n\n",classification_report(y_test,pred_KNN))
# Out:
# Accuracy score  0.8532167395377889
# confusion matrix
#
#  [[603 199]
#  [ 36 763]]
#
# classification report
#
#                precision    recall  f1-score   support
#
#          0.0       0.94      0.75      0.84       802
#          1.0       0.79      0.95      0.87       799
#
#     accuracy                           0.85      1601
#    macro avg       0.87      0.85      0.85      1601
# weighted avg       0.87      0.85      0.85      1601

# %%
# CROSS VALIDATION 
from sklearn.model_selection import cross_val_score
score=cross_val_score(RFC,x1,y1,cv=5)
print(score)
print(score.mean())
print('accuracy score',accuracy_score(y_test,pred_RFC))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_RFC)-score.mean()))
# Out:
# [0.76139913 0.64334791 0.79762648 0.86133666 0.9125    ]
# 0.7952420362273579
# accuracy score 0.9175515302935665
# Deference between accuracy score and cross val score : 0.12230949406620861

# %%
score1=cross_val_score(LR,x1,y1,cv=5)
print(score1)
print(score1.mean())
print('accuracy score',accuracy_score(y_test,pred_LR))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_LR)-score1.mean()))
# Out:
# [0.72891943 0.70643348 0.71018114 0.83260462 0.8475    ]
# 0.7651277326670831
# accuracy score 0.8069956277326671
# Deference between accuracy score and cross val score : 0.04186789506558397

# %%
score2=cross_val_score(SVM,x1,y1,cv=5)
print(score2)
print(score2.mean())
print('accuracy score',accuracy_score(y_test,pred_SVM))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_SVM)-score2.mean()))
# Out:
# [0.76514678 0.66583385 0.75765147 0.88007495 0.851875  ]
# 0.7841164116177389
# accuracy score 0.8732042473454091
# Deference between accuracy score and cross val score : 0.0890878357276702

# %%
score3=cross_val_score(GBC,x1,y1,cv=5)
print(score3)
print(score3.mean())
print('accuracy score',accuracy_score(y_test,pred_GBC))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_GBC)-score3.mean()))
# Out:
# [0.66333542 0.48532167 0.72017489 0.83947533 0.881875  ]
# 0.7180364615865085
# accuracy score 0.8844472204871955
# Deference between accuracy score and cross val score : 0.16641075890068702

# %%
score4=cross_val_score(ABC,x1,y1,cv=5)
print(score4)
print(score4.mean())
print('accuracy score',accuracy_score(y_test,pred_ABC))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_ABC)-score4.mean()))
# Out:
# [0.66396002 0.53466583 0.71392879 0.79762648 0.8525    ]
# 0.7125362273579013
# accuracy score 0.8513429106808245
# Deference between accuracy score and cross val score : 0.13880668332292312

# %%
score5=cross_val_score(BAGG,x1,y1,cv=5)
print(score5)
print(score5.mean())
print('accuracy score',accuracy_score(y_test,pred_BAGG))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_BAGG)-score5.mean()))
# Out:
# [0.72891943 0.56277327 0.78700812 0.83010618 0.893125  ]
# 0.7603863991255466
# accuracy score 0.891317926296065
# Deference between accuracy score and cross val score : 0.13093152717051837

# %%
score6=cross_val_score(ETC,x1,y1,cv=5)
print(score6)
print(score6.mean())
print('accuracy score',accuracy_score(y_test,pred_ETC))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_ETC)-score6.mean()))
# Out:
# [0.83010618 0.70830731 0.81886321 0.93254216 0.905     ]
# 0.8389637726420988
# accuracy score 0.9262960649594004
# Deference between accuracy score and cross val score : 0.08733229231730166

# %%
score7=cross_val_score(DT,x1,y1,cv=5)
print(score7)
print(score7.mean())
print('accuracy score',accuracy_score(y_test,pred_DT))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_DT)-score7.mean()))
# Out:
# [0.68457214 0.54465959 0.74515928 0.78326046 0.855625  ]
# 0.7226552935665209
# accuracy score 0.8338538413491567
# Deference between accuracy score and cross val score : 0.11119854778263583

# %%
score8=cross_val_score(KNN,x1,y1,cv=5)
print(score8)
print(score8.mean())
print('accuracy score',accuracy_score(y_test,pred_KNN))
print('Deference between accuracy score and cross val score :',(accuracy_score(y_test,pred_KNN)-score8.mean()))
# Out:
# [0.75452842 0.64834478 0.75765147 0.85259213 0.813125  ]
# 0.7652483603997501
# accuracy score 0.8532167395377889
# Deference between accuracy score and cross val score : 0.08796837913803879

# %%
# THE BEST PERFORMING MODEL IS lOGISTICREGRESSION BECAUSE THE DEFERENCE BETWEEN ACCURACY SCORE AND CROSS VAL SCORE IS LESS FOR THIS MODEL

# %%
# HYPER PARAMETER TUNING 
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'penalty':['l1','l2'],'solver':['liblinear']}

# %%
grid_search=GridSearchCV(LR,param_grid,cv=5,scoring='accuracy',error_score='raise')
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise', estimator=LogisticRegression(),
#              param_grid={'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'penalty': 'l1', 'solver': 'liblinear'}

# %%
model=LogisticRegression(penalty='l2',solver='liblinear')
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('Accuracy score ',accuracy_score(y_test,pred))
# Out:
# Accuracy score  0.8069956277326671

# %%
# after hyper parameter tuning getting the same accuracy 80.94
